# %% [markdown]
# # Data Exploration
#
# This explores historical UK short disclosures as of 2022-12-29.
#
# Findings:
# - It's difficult to tell when historical shorts were closed
#     - Funds disclose when their net short position crosses the 0.5% threshold
#     - However some historical shorts end above the threshold
#         - This could be due to delistings or ISIN changes, though it's hard to tell without further investigation
# - There are some (3) duplicates, though these are easy to deal with (take the max disclosed position)
#
# See https://www.fca.org.uk/markets/short-selling/notification-disclosure-net-short-positions for more details on the data.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from datetime import datetime, timedelta

from short_tracker.data import (
    query_all_sec_metadata, query_uk_si_disclosures,
    SHORT_URL_UK, DATE_COL, FUND_COL, ISIN_COL, SHORT_POS_COL,
    SHARE_ISSUER_COL, UK_DISCL_THRESHOLD,
)
from short_tracker.processing import (
    check_cur_hist_discl_overlap, remove_dupl_shorts, ffill_discl_data, calc_fund_short_flow_bounds
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
discl_data, rept_date = query_uk_si_disclosures(SHORT_URL_UK) # exp_upd_time
rept_date
# Out:
# datetime.date(2022, 12, 28)

# %%
cur_discl = discl_data['current']
hist_discl = discl_data['historic']
all_isins = pd.concat([cur_discl[ISIN_COL], hist_discl[ISIN_COL]]).unique()

assert not check_cur_hist_discl_overlap(cur_discl, hist_discl)

hist_discl = remove_dupl_shorts(hist_discl)

exp_max_discl_date = rept_date - timedelta(days=1)
max_discl_date = cur_discl[DATE_COL].max().date()

assert max_discl_date <= exp_max_discl_date
max_discl_date
# Out:
# Found 6 duplicated rows:                   Position Holder       Name of Share Issuer          ISIN  Net Short Position (%) Position Date
# 23713  Bercheva Opportunities Ltd                  EQTEC PLC  IE00BH3XCL94                    1.41    2018-03-28
# 23714  Bercheva Opportunities Ltd                  EQTEC PLC  IE00BH3XCL94                    2.19    2018-03-28
# 46092      Jane Street Group, LLC  MICRO FOCUS INTERNATIONAL  GB00BJ1F4N75                    0.64    2017-09-01
# 46093      Jane Street Group, LLC  MICRO FOCUS INTERNATIONAL  GB00BJ1F4N75                    0.00    2017-09-01
# 57953                  Roble S.L.     QUINDELL PORTFOLIO PLC  GB00BMTS9H89                    0.54    2014-02-28
# 57954                  Roble S.L.     QUINDELL PORTFOLIO PLC  GB00BMTS9H89                    0.61    2014-02-28
# Assuming the max disclosure is correct...
# datetime.date(2022, 12, 23)

# %%
cur_discl_ind = cur_discl.set_index([ISIN_COL, FUND_COL]).index

# disclosures previously opened by a fund that are now still open
# need to ffill these up to the current disclosures
# FIXME: this logic doesn't work, see below
cont_discl_ind = hist_discl.set_index([ISIN_COL, FUND_COL]).index.isin(cur_discl_ind)
cont_hist_discl = hist_discl.loc[cont_discl_ind]

cont_discl = pd.concat([cont_hist_discl, cur_discl])

cont_discl_ffill = ffill_discl_data(cont_discl, exp_max_discl_date, UK_DISCL_THRESHOLD)

# historical shorts not currently marked as open
closed_discl = hist_discl.loc[~cont_discl_ind]
closed_discl_ffill = ffill_discl_data(closed_discl, None, UK_DISCL_THRESHOLD)

# %%
max_closed_idx = closed_discl.groupby([FUND_COL, ISIN_COL])[[DATE_COL]].max().set_index(DATE_COL, append=True).index
latest_closed_shorts = closed_discl[closed_discl.set_index([FUND_COL, ISIN_COL, DATE_COL]).index.isin(max_closed_idx)]

unclosed_hist_shorts = latest_closed_shorts[latest_closed_shorts[SHORT_POS_COL]>=UK_DISCL_THRESHOLD].sort_values(by=DATE_COL)
unclosed_hist_shorts
# ... so our ffill logic doesn't work since some shorts end > the threshold.
# Out:
#                                          Position Holder  \
# 7114                              Anthion Management LLC
# 68696                                   QUANTATATIVE LTD
# 3531                         AQR Capital Management, LLC
# 8169          Bain Capital Public Equity Management, LLC
# 65791                            Oxford Asset Management
# 65640                            Oxford Asset Management
# 76576                     Wolverine Asset Management LLC
# 37052                           GSA Capital Partners LLP
# 65912                            Oxford Asset Management
# 65502                   Oceanwood Capital Management LLP
# 62729                       Newbrook Capital Advisors LP
# 30                        ABC Arbitrage Asset Management
# 40295             JMB Capital Partners Master Fund, L.P.
# 47425                            Long Pond Capital, L.P.
# 30643                    EverPoint Asset Management, LLC
# 67841                     Point72 Asset Management, L.P.
# 66354                                  PDT Partners, LLC
# 28634                  Discovery Capital Management, LLC
# 51497                                  Marshall Wace LLP
# 74733                         Trium Capital Managers LTD
# 44478              Jupiter Investment Management Limited
# 76160                  Wellington Management Company LLP
# 36795                                   GMT Capital Corp
# 66290                  P. Schoenfeld Asset Management LP
# 62983                              Numeric Investors LLC
# 74926                      UBS Asset Management (UK) Ltd
# 69234                                RYE BAY CAPITAL LLP
# 62940                              Numeric Investors LLC
# 41987                    Jane Street Global Trading, LLC
# 18663                          Bridgewater Associates LP
# 10036  BlackRock Institutional Trust Company, Nationa...
# 64067                          ODEY ASSET MANAGEMENT LLP
# 9385   BlackRock Institutional Trust Company, Nationa...
# 71653                         Silver Point Capital, L.P.
# 68988               Qube Research & Technologies Limited
# 45349              Kite Lake Capital Management (UK) LLP
# 58653                  Melqart Asset Management (UK) Ltd
# 74091                                   TT International
# 72088                                Squarepoint Ops LLC
# 71849                                Squarepoint Ops LLC
# 19887               Canada Pension Plan Investment Board
# 71939                                Squarepoint Ops LLC
# 39206                              Greenvale Capital LLP
# 4524                         AQR Capital Management, LLC
# 64397                          ODEY ASSET MANAGEMENT LLP
# 71465         Sculptor Capital Management Europe Limited
# 7276                                 Arena Investors, LP
# 38791                   Gladstone Capital Management LLP
# 44874                                KUVARI PARTNERS LLP
# 58655                  Melqart Asset Management (UK) Ltd
# 75951                      Värde Partners Europe Limited
# 62276                   Mirabella Financial Services LLP
#
#                Name of Share Issuer          ISIN Position Date  \
# 7114          VALIANT PETROLEUM PLC  GB00B2NJD643    2013-03-07
# 68696              RENOVO GROUP PLC  GB00B081NX89    2013-08-23
# 3531     EURASIAN NATURAL RESOURCES  GB00B29BCK10    2013-09-19
# 8169             WEIR GROUP PLC/THE  GB0009465807    2013-12-11
# 65791          F&C ASSET MANAGEMENT  GB0004658141    2014-03-20
# 65640          AFRICAN MINERALS LTD  BMG0114P1005    2014-06-30
# 76576             LONDON MINING PLC  GB00B1VZK334    2014-08-19
# 37052          AFRICAN MINERALS LTD  BMG0114P1005    2014-09-11
# 65912             LONDON MINING PLC  GB00B1VZK334    2014-09-23
# 65502          AFRICAN MINERALS LTD  BMG0114P1005    2014-10-08
# 62729             HOME RETAIL GROUP  GB00B19NKB76    2015-07-13
# 30        AGA RANGEMASTER GROUP PLC  GB00B2QMX606    2015-07-22
# 40295                     ALENT PLC  GB00BQ1XTV39    2015-10-26
# 47425  INTERCONTINENTAL HOTELS GROU  GB00BYXK6398    2015-12-02
# 30643                  LIVANOVA PLC  GB00BYMT0J19    2016-07-06
# 67841                  LIVANOVA PLC  GB00BYMT0J19    2016-07-11
# 66354        GW PHARMACEUTICALS PLC  GB0030544687    2016-11-22
# 28634        GW PHARMACEUTICALS PLC  GB0030544687    2016-11-28
# 51497        GW PHARMACEUTICALS PLC  GB0030544687    2016-12-02
# 74733          ANIMALCARE GROUP PLC  GB0032350695    2017-07-05
# 44478                       UBM Plc  JE00BD9WR069    2017-09-19
# 76160                   NOVAE GROUP  GB00B40SF849    2017-09-22
# 36795                 CARILLION PLC  GB0007365546    2017-10-09
# 66290    IMAGINATION TECH GROUP PLC  GB0009303123    2017-10-25
# 62983    IMAGINATION TECH GROUP PLC  GB0009303123    2017-11-02
# 74926                 DEBENHAMS PLC  GB00B126KH97    2017-11-03
# 69234                 CARILLION PLC  GB0007365546    2017-11-27
# 62940        GW PHARMACEUTICALS PLC  GB0030544687    2017-12-01
# 41987               CINEWORLD GROUP  GB00B15FWH70    2018-02-14
# 18663                OLD MUTUAL PLC  GB00B77J0862    2018-03-22
# 10036           PHOENIX GROUP HLDGS  KYG7091M1096    2018-11-06
# 64067                 DEBENHAMS PLC  GB00B126KH97    2019-01-22
# 9385            GREENCORE GROUP PLC  IE0003864109    2019-05-07
# 71653         THOMAS COOK GROUP PLC  GB00B1VYCH82    2019-05-29
# 68988   Invesco DB Agriculture Fund  US46140H1068    2019-06-13
# 45349         THOMAS COOK GROUP PLC  GB00B1VYCH82    2019-08-19
# 58653         THOMAS COOK GROUP PLC  GB00B1VYCH82    2019-09-16
# 74091         THOMAS COOK GROUP PLC  GB00B1VYCH82    2019-09-16
# 72088  Salarius Pharmaceuticals Inc  US79400X1072    2019-10-10
# 71849                   Aptinyx Inc  US03836N1037    2019-10-16
# 19887                   VALARIS PLC  GB00BJVJZD68    2019-11-25
# 71939        Iconix Brand Group Inc  US4510553054    2019-12-24
# 39206                   PLUS500 LTD  IL0011284465    2020-01-10
# 4524                 NMC HEALTH PLC  GB00B7FC0762    2020-02-24
# 64397           INTU PROPERTIES PLC  GB0006834344    2020-03-04
# 71465           SIRIUS MINERALS PLC  GB00B0DG3H29    2020-03-05
# 7276                LOW & BONAR PLC  GB0005363014    2020-05-07
# 38791       Burford Capital Limited  GG00B4L84979    2020-07-29
# 44874       Burford Capital Limited  GG00B4L84979    2020-09-03
# 58655                        TUI AG  DE000TUAG000    2020-09-17
# 75951                        TUI AG  DE000TUAG000    2020-12-03
# 62276               PREMIER OIL PLC  GB00B43G0577    2021-03-25
#
#        Net Short Position (%)
# 7114                     1.90
# 68696                    0.69
# 3531                     0.66
# 8169                     0.96
# 65791                    0.68
# 65640                    0.70
# 76576                    0.52
# 37052                    0.54
# 65912                    0.99
# 65502                    0.60
# 62729                    0.55
# 30                       1.26
# 40295                    0.89
# 47425                    0.53
# 30643                    0.65
# 67841                    1.08
# 66354                    0.55
# 28634                    0.99
# 51497                    1.80
# 74733                    0.67
# 44478                    0.50
# 76160                    0.63
# 36795                    0.60
# 66290                    1.53
# 62983                    0.76
# 74926                    1.72
# 69234                    2.02
# 62940                    1.87
# 41987                    0.61
# 18663                    0.50
# 10036                    0.59
# 64067                    7.70
# 9385                     0.56
# 71653                    0.77
# 68988                    0.64
# 45349                    1.00
# 58653                    1.00
# 74091                    3.83
# 72088                    0.61
# 71849                    0.69
# 19887                    3.00
# 71939                    0.69
# 39206                    0.78
# 4524                     0.69
# 64397                    3.64
# 71465                    1.47
# 7276                     1.12
# 38791                    1.18
# 44874                    0.52
# 58655                    0.63
# 75951                    0.99
# 62276                    1.14

# %%
ix = [FUND_COL, ISIN_COL, DATE_COL]
# closed_discl_ffill.set_index(ix).index.isin(cont_discl_ffill.set_index(ix).index).sum()
# cont_discl_ffill.set_index(ix).index.isin(closed_discl_ffill.set_index(ix).index).sum()

discl_ffill = pd.concat([closed_discl_ffill, cont_discl_ffill])
discl_ffill_ = discl_ffill[~discl_ffill.duplicated(subset=ix)]

pivot_discl = lambda df: df.pivot(index=DATE_COL, columns=FUND_COL, values=SHORT_POS_COL)

hist_discl_dict = {isin: pivot_discl(df) for isin, df in discl_ffill_.groupby(ISIN_COL)}

# %%
a = cont_discl_ffill

# %%
a
# Out:
#                  Position Holder Name of Share Issuer          ISIN  \
# 0               AHL Partners LLP             ASOS PLC  GB0030927254
# 1               AHL Partners LLP             ASOS PLC  GB0030927254
# 2               AHL Partners LLP             ASOS PLC  GB0030927254
# 3               AHL Partners LLP             ASOS PLC  GB0030927254
# 4               AHL Partners LLP             ASOS PLC  GB0030927254
# ...                          ...                  ...           ...
# 183985  XIB Asset Management Inc          SOLGOLD PLC  GB00B0WD0R35
# 183986  XIB Asset Management Inc          SOLGOLD PLC  GB00B0WD0R35
# 183987  XIB Asset Management Inc          SOLGOLD PLC  GB00B0WD0R35
# 183988  XIB Asset Management Inc          SOLGOLD PLC  GB00B0WD0R35
# 183989  XIB Asset Management Inc          SOLGOLD PLC  GB00B0WD0R35
#
#        Position Date  Net Short Position (%)
# 0         2019-01-09                    0.67
# 1         2019-01-10                    0.67
# 2         2019-01-11                    0.67
# 3         2019-01-14                    0.67
# 4         2019-01-15                    0.67
# ...              ...                     ...
# 183985    2022-12-21                    0.50
# 183986    2022-12-22                    0.50
# 183987    2022-12-23                    0.50
# 183988    2022-12-26                    0.50
# 183989    2022-12-27                    0.50
#
# [183990 rows x 5 columns]

# %%
a[a[FUND_COL]=='AHL Partners LLP']
# Out:
#        Position Holder Name of Share Issuer          ISIN Position Date  \
# 0     AHL Partners LLP             ASOS PLC  GB0030927254    2019-01-09
# 1     AHL Partners LLP             ASOS PLC  GB0030927254    2019-01-10
# 2     AHL Partners LLP             ASOS PLC  GB0030927254    2019-01-11
# 3     AHL Partners LLP             ASOS PLC  GB0030927254    2019-01-14
# 4     AHL Partners LLP             ASOS PLC  GB0030927254    2019-01-15
# ...                ...                  ...           ...           ...
# 1030  AHL Partners LLP             ASOS PLC  GB0030927254    2022-12-21
# 1031  AHL Partners LLP             ASOS PLC  GB0030927254    2022-12-22
# 1032  AHL Partners LLP             ASOS PLC  GB0030927254    2022-12-23
# 1033  AHL Partners LLP             ASOS PLC  GB0030927254    2022-12-26
# 1034  AHL Partners LLP             ASOS PLC  GB0030927254    2022-12-27
#
#       Net Short Position (%)
# 0                       0.67
# 1                       0.67
# 2                       0.67
# 3                       0.67
# 4                       0.67
# ...                      ...
# 1030                    0.90
# 1031                    0.90
# 1032                    0.90
# 1033                    0.90
# 1034                    0.90
#
# [1035 rows x 5 columns]

# %%
sec_metadata, err_isins = query_all_sec_metadata(all_isins, "ID_ISIN")
exch_codes = {k: [x['exchCode'] for x in v] for k, v in sec_metadata.items()}
print(len(err_isins))

# 140 outdated isins???
# Out:
# 140

# %%
from functools import reduce

ln_sec = {}

for k, v in sec_metadata.items():
    if "LN" in exch_codes[k]:
        ln_sec[k] = v[exch_codes[k].index("LN")]

sec_data_df = pd.DataFrame(ln_sec)

print(len(ln_sec), len(sec_metadata))
# Out:
# 501 637

# %%
import yfinance as yf
from tenacity import retry, wait_fixed

@retry(wait=wait_fixed(10))
def query_mkt_data(sec_id, period='max'):
    return yf.Ticker(sec_id).history(period=period)
    

mkt_data_err_isins = []
mkt_data = {}

for isin in all_isins:
    try:
        mkt_data[isin] = query_mkt_data(isin)
    except:
        mkt_data_err_isins.append(isin)

print(len(mkt_data), len(mkt_data_err_isins))
# Out:
# 777 0

# %%
UK_MKT_TICKER = "VUKE.L"
UK_MKT_SIZE_TICKER = "VMID.L"

mkt_tickers = [UK_MKT_TICKER, UK_MKT_SIZE_TICKER]

bm_data = {k: query_mkt_data(k) for k in mkt_tickers}

# %%
total_hist_discl_df = pd.DataFrame({k: v.sum(axis=1) for k, v in hist_discl_dict.items()})

# %%
def proc_mkt_data(df, col):
    df_ = df.copy()
    # print(k, df_.index.dtype)
    df_.index = df_.index.date
    return df_[col]
    

def mkt_data_to_df(data_dict, col):
    data_dict_ = {k: proc_mkt_data(v, col) for k, v in data_dict.items()}
    return pd.DataFrame(data_dict_)

# TODO: investigate why there's a lot of missing data - probably mostly delisted/changed isins
print(len([k for k, v in mkt_data.items() if v.empty]))

mkt_data_ = {k: v for k, v in mkt_data.items() if not v.empty}
mkt_data_ = {**mkt_data_, **bm_data}
mkt_data_ = {k: v.loc["2010-01-01":] for k, v in mkt_data_.items()}
# Out:
# 362

# %%
price_data = mkt_data_to_df(mkt_data_, "Close")

# %%
returns = price_data.ffill().pct_change()
np.sum(np.isinf(returns).values)
# Out:
# 0

# %%
m = yf.Ticker("MSFT")

# %%
m.stats()

# %%
# price_data[[k for k in unclosed_hist_shorts[ISIN_COL] if k in mkt_data_]]

# %%
total_hist_discl_df
# Out:
#                AEDFXA1EN018  AU000000FTE4  AU000000S320  BMG0114P1005  \
# Position Date
# 2012-10-31              NaN           NaN           NaN           NaN
# 2012-11-01              NaN           NaN           NaN          0.61
# 2012-11-02              NaN           NaN           NaN          0.61
# 2012-11-05              NaN           NaN           NaN          0.61
# 2012-11-06              NaN           NaN           NaN          0.61
# ...                     ...           ...           ...           ...
# 2022-12-21              NaN           NaN           NaN           NaN
# 2022-12-22              NaN           NaN           NaN           NaN
# 2022-12-23              NaN           NaN           NaN           NaN
# 2022-12-26              NaN           NaN           NaN           NaN
# 2022-12-27              NaN           NaN           NaN           NaN
#
#                BMG0440M1284  BMG4209G2077  BMG4593F1389  BMG5307C1055  \
# Position Date
# 2012-10-31              NaN           NaN           NaN           NaN
# 2012-11-01             2.68           NaN           NaN           NaN
# 2012-11-02             2.68           NaN           NaN           NaN
# 2012-11-05             2.68           NaN           NaN           NaN
# 2012-11-06             3.73           NaN           NaN           NaN
# ...                     ...           ...           ...           ...
# 2022-12-21              NaN           NaN           0.6           NaN
# 2022-12-22              NaN           NaN           0.6           NaN
# 2022-12-23              NaN           NaN           0.6           NaN
# 2022-12-26              NaN           NaN           0.6           NaN
# 2022-12-27              NaN           NaN           0.6           NaN
#
#                BMG5361W1047  BMG702781250  ...  US46138B1035  US46140H1068  \
# Position Date                              ...
# 2012-10-31              NaN           NaN  ...           NaN           NaN
# 2012-11-01             0.88           NaN  ...           NaN           NaN
# 2012-11-02             0.88           NaN  ...           NaN           NaN
# 2012-11-05             0.88           NaN  ...           NaN           NaN
# 2012-11-06             0.88           NaN  ...           NaN           NaN
# ...                     ...           ...  ...           ...           ...
# 2022-12-21              NaN           NaN  ...           NaN           NaN
# 2022-12-22              NaN           NaN  ...           NaN           NaN
# 2022-12-23              NaN           NaN  ...           NaN           NaN
# 2022-12-26              NaN           NaN  ...           NaN           NaN
# 2022-12-27              NaN           NaN  ...           NaN           NaN
#
#                US68234L3069  US79400X1072  USU7744C1063  VGG0472G1063  \
# Position Date
# 2012-10-31              NaN           NaN           NaN           NaN
# 2012-11-01              NaN           NaN           NaN           NaN
# 2012-11-02              NaN           NaN           NaN           NaN
# 2012-11-05              NaN           NaN           NaN          0.58
# 2012-11-06              NaN           NaN           NaN          0.65
# ...                     ...           ...           ...           ...
# 2022-12-21              NaN           NaN           NaN           NaN
# 2022-12-22              NaN           NaN           NaN           NaN
# 2022-12-23              NaN           NaN           NaN           NaN
# 2022-12-26              NaN           NaN           NaN           NaN
# 2022-12-27              NaN           NaN           NaN           NaN
#
#                VGG379591065  VGG4392T1075  ZAE000255360  ZAE000296554
# Position Date
# 2012-10-31              NaN           NaN           NaN           NaN
# 2012-11-01              NaN           NaN           NaN           NaN
# 2012-11-02              NaN           NaN           NaN           NaN
# 2012-11-05              NaN           NaN           NaN           NaN
# 2012-11-06              NaN           NaN           NaN           NaN
# ...                     ...           ...           ...           ...
# 2022-12-21              NaN           NaN          0.79           NaN
# 2022-12-22              NaN           NaN          0.79           NaN
# 2022-12-23              NaN           NaN          0.79           NaN
# 2022-12-26              NaN           NaN          0.79           NaN
# 2022-12-27              NaN           NaN          0.79           NaN
#
# [2650 rows x 777 columns]
